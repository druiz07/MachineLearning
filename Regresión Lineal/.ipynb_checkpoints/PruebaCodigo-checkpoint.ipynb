# %%
from utils import load_data
from linear_reg import gradient_descent 
from linear_reg import compute_cost
from linear_reg import compute_gradient
from  public_tests import compute_cost_test
from  public_tests import compute_gradient_test
from  public_tests import  compute_gradient_descent_test
import numpy as np
import matplotlib.pyplot as plt

compute_cost_test(compute_cost)
compute_gradient_test(compute_gradient)

x,y =load_data()

w,b, structure = gradient_descent(x, y, 0, 0, compute_cost, compute_gradient, 0.01, 1500)
print(w)
print(b)

compute_gradient_descent_test(w,b)
plt.scatter(x, y, color='blue', label='Datos de entrenamiento')
plt.plot(x, w * x + b, color='red', label='Recta de regresión')
plt.xlabel('Variable independiente')
plt.ylabel('Variable dependiente')
plt.title('Recta de Regresión')
plt.legend()
plt.show()
# Out:
# Testing: compute_cost_test
# Cost case 1
# Case 1 passed!
# Cost case 2
# Case 2 passed!
# Cost case 3
# Case 3 passed!
# Cost case 4
# Case 4 passed!
# Cost case 5
# Case 5 passed!
# All tests passed!
# Testing: compute_gradient_test
# Using X with shape (4, 1)
# Case 1
# 0.0 0.0
# Case 1 passed!
# Case 2
# Case 2 passed!
# All tests passed!
# 1.1559864086837552
# -3.553366921533516
# Testing: compute_gradient_descent_test
# Case 1 0.49258550885962693
# Case 1 passed!
# Case 24.53853793925277
# Case 2 passed!
# All tests passed!
